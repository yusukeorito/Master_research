# %% [markdown]
# <a href="https://colab.research.google.com/github/yusukeorito/Master_research/blob/main/Exp011_Train_model_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
問題設定：分類問題
学習データサイズ M：訓練6000、テスト10000
レイヤー数L : 10 or 20
ネットワークの幅N:100
ノイズパラメータλ:1.5

"""
# Out:
# '\n問題設定：分類問題\n学習データサイズ M：訓練6000、テスト10000\nレイヤー数L : 10 or 20\nネットワークの幅N:100\nノイズパラメータλ:1.5\n\n'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Master_research/exp010
# Out:
# /content/drive/MyDrive/Master_research/exp010

# %%
import os
import random
import pickle

import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import Callback,ModelCheckpoint
from tensorflow.keras.layers import Dense,BatchNormalization,Activation
from tensorflow.keras.callbacks import Callback,ModelCheckpoint
from tensorflow.keras.activations import relu
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

class CFG:
    task = 'classification'
    seed1 = 820
    seed2=314
    data_seed = 42
    save_dir = '../Model/'
    output_dir = '../Output/'
    L=10
    M=60000
    N=100
    #A=1.5#ノイズの強さ
    C=50#結合を持つweightの個数
    ini_type = 'A'
    train='train'
    mean = 0.5  # 平均
    std_dev = 0.1  # 標準偏差
    layer_name_list =['batch_normalization1', 'batch_normalization2', 'batch_normalization3',
                   'batch_normalization4', 'batch_normalization5', 'batch_normalization6', 'batch_normalization7', 'batch_normalization8',
                   'batch_normalization9','batch_normalization10',]

def set_seed(seed):
    tf.random.set_seed(seed)
    # optional
    # for numpy.random
    np.random.seed(seed)
    # for built-in random
    random.seed(seed)
    # for hash seed
    os.environ["PYTHONHASHSEED"] = str(seed)

def preprocess_data(X_train_, y_train_):
    # Rasterize and normalize samples

    X_train_ = X_train_.reshape(X_train_.shape[0], -1)
    y_train_ = y_train_.reshape(y_train_.shape[0], -1)

    X_train_ = X_train_ / 255
    y_train_ = y_train_ / 255

    # Use 32-bit instead of 64-bit float
    X_train_ = X_train_.astype("float32")
    y_train_ = y_train_.astype("float32")

    return X_train_, y_train_

def PCA_SS_func(input_train,input_test):
  input_d=100
  # Make an instance of the Model
  pca = PCA(n_components=input_d)
  scaler = StandardScaler()

  train_img = pca.fit_transform(input_train)
  print(np.sum(pca.explained_variance_ratio_[:]))
  train_img =scaler.fit_transform(train_img)
  test_img = pca.transform(input_test)
  test_img =scaler.transform(test_img)
  print('Train:',train_img.shape)
  print('Test:',test_img.shape)
  return train_img, test_img, pca, scaler
"""
class LogEpochIntermediateCallcack(Callback):
  def __init__(self, layer_name_list,model_num):
    self.layer_name_list = layer_name_list
    self.spin_dict = {key: [] for key in self.layer_name_list}
    #self.spin_dict_test = {key: [] for key in self.layer_name_list}
    self.nextMeas=1
    self.model_num = model_num


  def on_train_begin(self, batch, logs=None):
    self.spin_dict['time'] = [0]
    #self.spin_dict_test['time'] = [0]
    for l in self.layer_name_list:
      intermediate_layer_model = tf.keras.Model(inputs=self.model.input,outputs=self.model.get_layer(l).output)
      if CFG.M == 60000:
        intermediate_output = intermediate_layer_model.predict(X_train_)
      else:
        ntermediate_output = intermediate_layer_model.predict(X_train)
      #intermediate_output_test = intermediate_layer_model.predict(test_in)
      tf.keras.backend.clear_session()
      self.spin_dict[l].append(intermediate_output)
      #self.spin_dict_test[l].append(intermediate_output_test)

  def on_epoch_begin(self, epoch, logs=None):
      self.ep = epoch

  def on_epoch_end(self, batch, logs):
      if self.ep+1==self.nextMeas:
        for l in self.layer_name_list:
          intermediate_layer_model = tf.keras.Model(inputs=self.model.input,outputs=self.model.get_layer(l).output)
          if CFG.M == 60000:
            intermediate_output = intermediate_layer_model.predict(X_train_)
          else:
            intermediate_output = intermediate_layer_model.predict(X_train)
          #intermediate_output_test = intermediate_layer_model.predict(test_in)
          tf.keras.backend.clear_session()
          self.spin_dict[l].append(intermediate_output)
          #self.spin_dict_test[l].append(intermediate_output_test)
        self.spin_dict['time']+=[self.ep+1]
        #self.spin_dict_test['time']+=[self.ep+1]
        self.nextMeas=int(self.nextMeas*1.1)
        if self.ep+1==self.nextMeas:
          self.nextMeas = self.nextMeas+1


  def on_train_end(self, logs=None):
    for l in self.layer_name_list:
      self.spin_dict[l] = np.array(self.spin_dict[l])
      #self.spin_dict_test[l] = np.array(self.spin_dict_test[l])
    with open(f'./Output/Spin/M{CFG.M}/model{self.model_num}_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
      pickle.dump(self.spin_dict, handle)
    #with open(f'./Output/Spin/M600/model{self.model_num}_M{CFG.M}_L{CFG.L}_A{CFG.A}_test.txt','wb') as handle:
        #pickle.dump(self.spin_dict_test, handle)
"""


class LogEpochIntermediateCallcack(Callback):
    def __init__(self, layer_name_list, model_num):
        self.layer_name_list = layer_name_list
        self.spin_dict = {key: [] for key in self.layer_name_list}
        self.nextMeas = 1
        self.model_num = model_num

    def on_train_begin(self, batch, logs=None):
        self.spin_dict['time'] = [0]

        for l in self.layer_name_list:
            intermediate_layer_model = tf.keras.Model(inputs=self.model.input, outputs=self.model.get_layer(l).output)

            if CFG.M == 60000:
                intermediate_output = intermediate_layer_model.predict(X_train_)
            else:
                intermediate_output = intermediate_layer_model.predict(X_train)

            tf.keras.backend.clear_session()
            self.spin_dict[l].append(intermediate_output)

    def on_epoch_begin(self, epoch, logs=None):
        self.ep = epoch

    def on_epoch_end(self, batch, logs):
        if self.ep + 1 == self.nextMeas:
            for l in self.layer_name_list:
                intermediate_layer_model = tf.keras.Model(inputs=self.model.input, outputs=self.model.get_layer(l).output)

                if CFG.M == 60000:
                    intermediate_output = intermediate_layer_model.predict(X_train_)
                else:
                    intermediate_output = intermediate_layer_model.predict(X_train)

                tf.keras.backend.clear_session()
                self.spin_dict[l].append(intermediate_output)

            self.spin_dict['time'] += [self.ep + 1]
            self.nextMeas = int(self.nextMeas * 1.1)

            if self.ep + 1 == self.nextMeas:
                self.nextMeas = self.nextMeas + 1


    def on_train_end(self, logs=None):
        for l in self.layer_name_list:
            self.spin_dict[l] = np.array(self.spin_dict[l])

        with open(f'./Output/Spin/M{CFG.M}/model{self.model_num}_stopW_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt', 'wb') as handle:
            pickle.dump(self.spin_dict, handle)


def add_gaussian_noise(image, mean, std_dev, alpha):
    noise = np.random.normal(mean, std_dev, image.shape)
    noisy_image = image + alpha * noise
    return np.clip(noisy_image, 0, 1)  # ピクセル値を0から1の範囲にクリップ




class CustomConstraint(tf.keras.constraints.Constraint):
    def __init__(self, mask, const):
        self.mask = mask
        self.const = const

    def __call__(self, w):
        # マスク行列を使用して、指定された部分を0で固定する
        w.assign(tf.math.multiply(w, self.mask) + self.const)
        return w


def get_mask(shape, C, specified_number, dtype=int):
    masks = np.zeros(shape)
    consts = np.random.normal(size=shape)
    for col in range(shape[1]):
        non_zero_indices = np.random.choice(shape[0], C, replace=False)
        masks[non_zero_indices, col] = 1
        consts[non_zero_indices, col] = 0
    masks = tf.constant(masks, dtype=tf.float32)
    consts = tf.constant(consts, dtype=tf.float32)
    return masks, consts




def create_model(params:dict,w_initializer,Mask_list,Const_list):
    """
    Creates a neural network model based on the given parameters.

    Args:
        params (dict): Dictionary containing model parameters.

    Returns:
        tf.keras.Model: Compiled neural network model.
    """
    model = Sequential(name='custom_model')
    model.add(Dense(params['width'], kernel_initializer=w_initializer,bias_initializer=params['bias_initializer'],input_shape=(params['input_size'],), name='Affine1',kernel_constraint=CustomConstraint(mask=Mask_list[0],const=Const_list[0])))
    model.add(BatchNormalization(name='batch_normalization1'))
    model.add(Activation('relu', name='activation1'))
    for i in range(1, params['num_layers'] - 1):
        model.add(Dense(params['width'], kernel_initializer=w_initializer,bias_initializer=params['bias_initializer'],name=f'Affine{i+1}',kernel_constraint=CustomConstraint(mask=Mask_list[i],const=Const_list[i])))
        model.add(BatchNormalization(name=f'batch_normalization{i+1}'))
        model.add(Activation('relu',name=f'activation{i+1}'))

    model.add(Dense(params['output_size'],kernel_initializer=w_initializer,bias_initializer=params['bias_initializer'],name='output',kernel_constraint=CustomConstraint(mask=Mask_list[9],const=Const_list[9])))
    model.add(BatchNormalization(name=f'batch_normalization{params["num_layers"]}'))
    model.add(Activation('softmax', name=f'activation{params["num_layers"]}'))
    model.compile(loss=params['loss'], optimizer='adam',metrics=params['metrics']
                  )
    return model


def calc_q_(A: np.ndarray, B: np.ndarray) -> float:
    M, N = A.shape
    dot_product = np.dot(A.T, B)
    x = np.sum(dot_product ** 2)
    x /= N * M * M
    x -= N / M
    return x

def calc_sim_q(A: np.ndarray, B: np.ndarray) -> float:
  mean = A * B
  sim_q = np.mean(mean)
  return sim_q

def get_sim_q(spinA, spinB):
  q_dict={'time':spin_A['time']}
  for l in tqdm(CFG.layer_name_list):
      q_list=[]
      for i in range(len(spin_A[l])):
          q = get_sim_q(spin_A[l][i],spin_B[l][i])
          q_list.append(q)
      q_dict[l]=q_list
  with open(f'./Output/Overlap/q/M{CFG.M}/sim_q_stopW_ini{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
        pickle.dump(q_dict, handle)
  return q_dict

def get_q2(spinA, spinB):
    qab_dict={'time':spinA['time']}#時刻の初期化
    qaa_dict={'time':spinA['time']}
    q2_dict={'time':spinA['time']}
    for l in tqdm(CFG.layer_name_list):
        qab_list=[]
        qaa_list=[]
        q2_list=[]
        for i in range(len(spinA[l])):
            ab = calc_q_(spinA[l][i],spinB[l][i])
            aa= calc_q_(spinA[l][i],spinA[l][i])
            bb = calc_q_(spinB[l][i],spinB[l][i])
            q2 = ab/(np.sqrt(aa)*np.sqrt(bb))
            qab_list.append(ab)
            qaa_list.append(aa)
            q2_list.append(q2)
        qab_dict[l] = qab_list
        qaa_dict[l] = qaa_list
        q2_dict[l] = q2_list
    """
    with open(f'./Output/Overlap/q/{CFG.alg}_qab_norm_M{CFG.M}_L{CFG.L}_A{CFG.A}_{CFG.train}.txt','wb') as handle:
        pickle.dump(qab_dict, handle)
    with open(f'./Output/Overlap/q/{CFG.alg}_qaa_norm_M{CFG.M}_L{CFG.L}_A{CFG.A}_{CFG.train}.txt','wb') as handle:
        pickle.dump(qaa_dict, handle)
    """
    with open(f'./Output/Overlap/q/M{CFG.M}/q2_norm_stopW_ini{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
        pickle.dump(q2_dict, handle)
    return qab_dict, qaa_dict, q2_dict



def get_layer_overlap(qab:dict,qaa:dict,q2:dict):
  layer_dict={}
  layer_q2=[]
  layer_qab=[]
  layer_qaa=[]

  for i, l in enumerate(CFG.layer_name_list):
      layer_q2.append(q2[l][-1])#平衡状態のOverlapを取得
      layer_qab.append(qab[l][-1])
      layer_qaa.append(qaa[l][-1])
  layer_dict['q2']=layer_q2
  layer_dict['qab']=layer_qab
  layer_dict['qaa']=layer_qaa

  with open(f'./Output/Overlap/Layer_q/M{CFG.M}/layerq_norm_stopW_ini{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
        pickle.dump(layer_dict, handle)
  return layer_dict

def get_normalized_spin(SpinA, SpinB):
  spinA_norm = SpinA.copy()
  spinB_norm = SpinB.copy()
  for l in tqdm(CFG.layer_name_list):
        squared_sum_A = np.sum(SpinA[l]**2, axis=2)
        squared_sum_B = np.sum(SpinB[l]**2, axis=2)
        # 規格化定数を計算
        normalization_constA = np.sqrt(100 / squared_sum_A)
        normalization_constB = np.sqrt(100 / squared_sum_B)
        # 規格化した配列を計算
        spinA_norm[l] = SpinA[l] * normalization_constA[:, :, np.newaxis]
        spinB_norm[l] = SpinB[l] * normalization_constB[:, :, np.newaxis]

  return spinA_norm, spinB_norm



model_params = {
    'num_layers':CFG.L,
    'input_size': 100,#width of network
    'output_size': 10,
    'batch_size':256,
    'width':100,
    'epochs':3000,
    'metrics':'accuracy',
    'loss':'sparse_categorical_crossentropy',
    'activation':'relu',
    'activation_last':'softmax',
    #'weight_initializer': tf.keras.initializers.RandomNormal(mean=0.0, stddev=1),
    'bias_initializer_value': 0.1,
    'bias_initializer': tf.keras.initializers.Constant(0.1),
    'optimizer':'adam',
}

# %%
print('='*15+'Data Load'+'='*15)
set_seed(seed=CFG.data_seed)
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train),(X_test, y_test) = fashion_mnist.load_data()
del fashion_mnist
print(X_train.shape)
print(X_test.shape)

print('='*15+'Preprocess data'+'='*15)
X_train, X_test = preprocess_data(X_train, X_test)


idx = np.random.choice(X_train.shape[0], size=CFG.M, replace=False)
X_train = X_train[idx]
y_train = y_train[idx]
n_classes = len(np.unique(y_train))

print('N_classes:',n_classes)
print('Train size:',X_train.shape, 'Test size:', y_train.shape)


print('='*15+'PCA'+'='*15)
X_train,X_test, pca1, scaler1 = PCA_SS_func(X_train, X_test)
print('Train size after PCA:',X_train.shape, 'Test size after PCA:', X_test.shape)

if CFG.M == 60000:
  print('M=60000')
  idx = np.random.choice(X_train.shape[0], size=6000, replace=False)
  X_train_ = X_train[idx]
  y_train_ = y_train[idx]
  print('X_train for mesure:',X_train_.shape,'y_train for mesure:',y_train_.shape, )

print('='*15+'get_mask'+'='*15)
mask_list = []
const_list = []
for i in range(CFG.L-1):
  mask,const = get_mask(shape=(100,100),C=CFG.C,specified_number=5)
  mask_list.append(mask)
  const_list.append(const)

if CFG.task == 'classification':
  print('='*15+'task is classification'+'='*15)
  mask, const = get_mask(shape=(100,10),C=CFG.C,specified_number=5)
  mask_list.append(mask)
  const_list.append(const)

"""
print('='*15+'Build model1'+'='*15)
set_seed(CFG.seed1)
w_intializer1 = tf.keras.initializers.RandomNormal(mean=0, stddev=1)
model1 = create_model(params=model_params, w_initializer=w_intializer1,Mask_list=mask_list ,Const_list=const_list)
print(model1.layers[3].get_weights()[0])

print('='*15+'Train model1'+'='*15)
history1 = model1.fit(X_train, y_train,
                batch_size=model_params["batch_size"],
                epochs=model_params["epochs"],
                verbose=1,
                shuffle=True,
                validation_data=(X_test, y_test),
                callbacks=[LogEpochIntermediateCallcack(layer_name_list=CFG.layer_name_list,model_num='001')]
                )

print('='*15+'Save loss and acc'+'='*15)
with open(f'./Output/Loss/M{CFG.M}/perform001_ini{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
        pickle.dump(history1.history, handle)
"""

print('='*15+'build model2'+'='*15)
set_seed(CFG.seed2)
w_intializer2 = tf.keras.initializers.RandomNormal(mean=0, stddev=1)
model2 = create_model(params=model_params, w_initializer=w_intializer2, Mask_list=mask_list ,Const_list=const_list)
print(model2.layers[3].get_weights()[0])
print('='*15+'Train model2'+'='*15)
history2 = model2.fit(X_train, y_train,
                batch_size=model_params["batch_size"],
                epochs=model_params["epochs"],
                verbose=1,
                shuffle=True,
                validation_data=(X_test, y_test),
                callbacks=[LogEpochIntermediateCallcack(layer_name_list=CFG.layer_name_list,model_num='002')]
                )

print('='*15+'Save loss and acc'+'='*15)
with open(f'./Output/Loss/M{CFG.M}/perform002_ini{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','wb') as handle:
        pickle.dump(history2.history, handle)

print('='*15+'get spin'+'='*15)
with open(f'./Output/Spin/M{CFG.M}/model001_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','rb') as f:
    spin_A=pickle.loads(f.read())

with open(f'./Output/Spin/M{CFG.M}/model002_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','rb') as f:
    spin_B=pickle.loads(f.read())


print('='*15+'get calc'+'='*15)
A_norm, B_norm = get_normalized_spin(spin_A, spin_B)
qab, qaa, q2 = get_q2(A_norm,B_norm)
sim_q = get_q2(spin_A, spin_B)
layer_q = get_layer_overlap(qab,qaa,q2)
# Out:
# ===============Data Load===============
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)
# ===============Preprocess data===============
# N_classes: 10
# Train size: (60000, 784) Test size: (60000,)
# ===============PCA===============
# 0.91186124
# Train: (60000, 100)
# Test: (10000, 100)
# Train size after PCA: (60000, 100) Test size after PCA: (10000, 100)
# M=60000
# X_train for mesure: (6000, 100) y_train for mesure: (6000,)
# ===============get_mask===============
# ===============task is classification===============
# ===============build model2===============
# /usr/local/lib/python3.10/dist-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# [[ 0.9125702   1.0695566  -0.17167082 ... -0.09951374  0.72831595
#   -0.23625985]
#  [ 0.6600948   0.06240575  1.3144156  ... -1.8161316  -0.00564129
#    0.1620477 ]
#  [ 1.0321238   0.15680301 -1.7170254  ...  1.4370385   1.405816
#    1.1456367 ]
#  ...
#  [-1.3542069  -0.3898817   0.22639309 ... -1.5649254   1.3800268
#    0.6186452 ]
#  [ 0.73457015  0.46793255  1.422731   ... -0.47923353 -0.45793504
#    0.32027408]
#  [-0.00762544 -0.38873342 -0.4980457  ... -0.58920044 -0.34291363
#   -1.7683132 ]]
# ===============Train model2===============
# 188/188 [==============================] - 3s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# Epoch 1/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 17s 38ms/step - loss: 2.2660 - accuracy: 0.2094 - val_loss: 2.3181 - val_accuracy: 0.2803
# Epoch 2/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 1.8185 - accuracy: 0.3809 - val_loss: 1.6584 - val_accuracy: 0.4421
# Epoch 3/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 38ms/step - loss: 1.5022 - accuracy: 0.5063 - val_loss: 1.3502 - val_accuracy: 0.5556
# Epoch 4/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 1.2276 - accuracy: 0.5995 - val_loss: 1.1136 - val_accuracy: 0.6312
# Epoch 5/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 1.0195 - accuracy: 0.6674 - val_loss: 0.9492 - val_accuracy: 0.6818
# Epoch 6/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.8708 - accuracy: 0.7124 - val_loss: 0.8308 - val_accuracy: 0.7209
# Epoch 7/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 39ms/step - loss: 0.7652 - accuracy: 0.7470 - val_loss: 0.7491 - val_accuracy: 0.7466
# Epoch 8/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 37ms/step - loss: 0.6879 - accuracy: 0.7705 - val_loss: 0.6897 - val_accuracy: 0.7646
# Epoch 9/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 39ms/step - loss: 0.6308 - accuracy: 0.7863 - val_loss: 0.6480 - val_accuracy: 0.7781
# Epoch 10/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 38ms/step - loss: 0.5865 - accuracy: 0.8004 - val_loss: 0.6145 - val_accuracy: 0.7910
# Epoch 11/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 38ms/step - loss: 0.5498 - accuracy: 0.8128 - val_loss: 0.5878 - val_accuracy: 0.7981
# Epoch 12/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 38ms/step - loss: 0.5197 - accuracy: 0.8211 - val_loss: 0.5668 - val_accuracy: 0.8033
# Epoch 13/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 10s 38ms/step - loss: 0.4930 - accuracy: 0.8297 - val_loss: 0.5488 - val_accuracy: 0.8086
# Epoch 14/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.4716 - accuracy: 0.8367 - val_loss: 0.5335 - val_accuracy: 0.8152
# Epoch 15/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.4550 - accuracy: 0.8415 - val_loss: 0.5200 - val_accuracy: 0.8189
# Epoch 16/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.4358 - accuracy: 0.8479 - val_loss: 0.5100 - val_accuracy: 0.8200
# Epoch 17/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0
3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1127 - accuracy: 0.9603 - val_loss: 0.6811 - val_accuracy: 0.8370
# Epoch 101/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1101 - accuracy: 0.9600 - val_loss: 0.6832 - val_accuracy: 0.8365
# Epoch 102/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1114 - accuracy: 0.9600 - val_loss: 0.6932 - val_accuracy: 0.8373
# Epoch 103/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.1078 - accuracy: 0.9610 - val_loss: 0.6916 - val_accuracy: 0.8378
# Epoch 104/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1095 - accuracy: 0.9609 - val_loss: 0.6899 - val_accuracy: 0.8395
# Epoch 105/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1088 - accuracy: 0.9614 - val_loss: 0.6913 - val_accuracy: 0.8375
# Epoch 106/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1069 - accuracy: 0.9617 - val_loss: 0.7025 - val_accuracy: 0.8349
# Epoch 107/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.1060 - accuracy: 0.9621 - val_loss: 0.6992 - val_accuracy: 0.8397
# Epoch 108/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1064 - accuracy: 0.9626 - val_loss: 0.7083 - val_accuracy: 0.8359
# Epoch 109/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1052 - accuracy: 0.9613 - val_loss: 0.7046 - val_accuracy: 0.8370
# Epoch 110/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1035 - accuracy: 0.9627 - val_loss: 0.7128 - val_accuracy: 0.8352
# Epoch 111/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1004 - accuracy: 0.9635 - val_loss: 0.7081 - val_accuracy: 0.8344
# Epoch 112/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0978 - accuracy: 0.9650 - val_loss: 0.7118 - val_accuracy: 0.8378
# Epoch 113/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 37ms/step - loss: 0.1010 - accuracy: 0.9640 - val_loss: 0.7167 - val_accuracy: 0.8382
# Epoch 114/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0979 - accuracy: 0.9644 - val_loss: 0.7192 - val_accuracy: 0.8351
# Epoch 115/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0984 - accuracy: 0.9645 - val_loss: 0.7341 - val_accuracy: 0.8392
# Epoch 116/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0934 - accuracy: 0.9659 - val_loss: 0.7338 - val_accuracy: 0.8348
# Epoch 117/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0987 - accuracy: 0.9641 - val_loss: 0.7380 - val_accuracy: 0.8358
# Epoch 118/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0983 - accuracy: 0.9640 - val_loss: 0.7348 - val_accuracy: 0.8362
# Epoch 119/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0980 - accuracy: 0.9649 - val_loss: 0.7320 - val_accuracy: 0.8373
# Epoch 120/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0957 - accuracy: 0.9661 - val_loss: 0.7368 - val_accuracy: 0.8348
# Epoch 121/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0959 - accuracy: 0.9653 - val_loss: 0.7451 - val_accuracy: 0.8361
# Epoch 122/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0953 - accuracy: 0.9647 - val_loss: 0.7440 - val_accuracy: 0.8358
# Epoch 123/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0927 - accuracy: 0.9662 - val_loss: 0.7439 - val_accuracy: 0.8385
# Epoch 124/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0895 - accuracy: 0.9672 - val_loss: 0.7394 - val_accuracy: 0.8370
# Epoch 125/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0901 - accuracy: 0.9670 - val_loss: 0.7385 - val_accuracy: 0.8359
# Epoch 126/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0852 - accuracy: 0.9697 - val_loss: 0.7490 - val_accuracy: 0.8376
# Epoch 127/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0890 - accuracy: 0.9677 - val_loss: 0.7485 - val_accuracy: 0.8374
# Epoch 128/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0873 - accuracy: 0.9689 - val_loss: 0.7526 - val_accuracy: 0.8405
# Epoch 129/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0880 - accuracy: 0.9679 - val_loss: 0.7645 - val_accuracy: 0.8391
# Epoch 130/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0868 - accuracy: 0.9686 - val_loss: 0.7658 - val_accuracy: 0.8415
# Epoch 131/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0879 - accuracy: 0.9676 - val_loss: 0.7596 - val_accuracy: 0.8381
# Epoch 132/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0870 - accuracy: 0.9689 - val_loss: 0.7667 - val_accuracy: 0.8399
# Epoch 133/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0841 - accuracy: 0.9690 - val_loss: 0.7733 - val_accuracy: 0.8365
# Epoch 134/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0848 - accuracy: 0.9691 - val_loss: 0.7865 - val_accuracy: 0.8392
# Epoch 135/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0832 - accuracy: 0.9709 - val_loss: 0.7800 - val_accuracy: 0.8356
# Epoch 136/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0829 - accuracy: 0.9701 - val_loss: 0.7741 - val_accuracy: 0.8385
# Epoch 137/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0815 - accuracy: 0.9707 - val_loss: 0.7858 - val_accuracy: 0.8371
# Epoch 138/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0817 - accuracy: 0.9706 - val_loss: 0.7847 - val_accuracy: 0.8368
# Epoch 139/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0815 - accuracy: 0.9711 - val_loss: 0.7840 - val_accuracy: 0.8367
# Epoch 140/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0788 - accuracy: 0.9722 - val_loss: 0.7941 - val_accuracy: 0.8372
# Epoch 141/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0795 - accuracy: 0.9710 - val_loss: 0.7938 - val_accuracy: 0.8359
# Epoch 142/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0814 - accuracy: 0.9706 - val_loss: 0.7965 - val_accuracy: 0.8375
# Epoch 143/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0780 - accuracy: 0.9717 - val_loss: 0.8001 - val_accuracy: 0.8370
# Epoch 144/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0803 - accuracy: 0.9709 - val_loss: 0.8012 - val_accuracy: 0.8373
# Epoch 145/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0777 - accuracy: 0.9722 - val_loss: 0.8017 - val_accuracy: 0.8408
# Epoch 146/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0779 - accuracy: 0.9717 - val_loss: 0.8019 - val_accuracy: 0.8384
# Epoch 147/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0777 - accuracy: 0.9724 - val_loss: 0.8050 - val_accuracy: 0.8394
# Epoch 148/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0782 - accuracy: 0.9719 - val_loss: 0.8048 - val_accuracy: 0.8384
# Epoch 149/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# ...
# Epoch 204/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0569 - accuracy: 0.9795 - val_loss: 0.8985 - val_accuracy: 0.8403
# Epoch 205/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0596 - accuracy: 0.9788 - val_loss: 0.9089 - val_accuracy: 0.8374
# Epoch 206/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0553 - accuracy: 0.9800 - val_loss: 0.9090 - val_accuracy: 0.8396
# Epoch 207/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0532 - accuracy: 0.9815 - val_loss: 0.9088 - val_accuracy: 0.8395
# Epoch 208/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0559 - accuracy: 0.9803 - val_loss: 0.9191 - val_accuracy: 0.8369
# Epoch 209/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0544 - accuracy: 0.9803 - val_loss: 0.9141 - val_accuracy: 0.8388
# Epoch 210/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0585 - accuracy: 0.9787 - val_loss: 0.9124 - val_accuracy: 0.8391
# Epoch 211/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0536 - accuracy: 0.9809 - val_loss: 0.9196 - val_accuracy: 0.8398
# Epoch 212/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0537 - accuracy: 0.9815 - val_loss: 0.9224 - val_accuracy: 0.8376
# Epoch 213/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0549 - accuracy: 0.9805 - val_loss: 0.9222 - val_accuracy: 0.8397
# Epoch 214/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0543 - accuracy: 0.9809 - val_loss: 0.9228 - val_accuracy: 0.8390
# Epoch 215/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0533 - accuracy: 0.9812 - val_loss: 0.9288 - val_accuracy: 0.8356
# Epoch 216/3000
# 235/235 [==============================] - 4s 12ms/step - loss: 0.0542 - accuracy: 0.9809 - val_loss: 0.9226 - val_accuracy: 0.8368
# Epoch 217/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0530 - accuracy: 0.9808 - val_loss: 0.9195 - val_accuracy: 0.8381
# Epoch 218/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0530 - accuracy: 0.9808 - val_loss: 0.9274 - val_accuracy: 0.8375
# Epoch 219/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0537 - accuracy: 0.9810 - val_loss: 0.9229 - val_accuracy: 0.8380
# Epoch 220/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0556 - accuracy: 0.9803 - val_loss: 0.9295 - val_accuracy: 0.8378
# Epoch 221/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0544 - accuracy: 0.9810 - val_loss: 0.9231 - val_accuracy: 0.8379
# Epoch 222/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0533 - accuracy: 0.9813 - val_loss: 0.9455 - val_accuracy: 0.8351
# Epoch 223/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0518 - accuracy: 0.9818 - val_loss: 0.9294 - val_accuracy: 0.8382
# Epoch 224/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0529 - accuracy: 0.9817 - val_loss: 0.9284 - val_accuracy: 0.8411
# Epoch 225/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0526 - accuracy: 0.9813 - val_loss: 0.9335 - val_accuracy: 0.8375
# Epoch 226/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0514 - accuracy: 0.9820 - val_loss: 0.9416 - val_accuracy: 0.8373
# Epoch 227/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0491 - accuracy: 0.9822 - val_loss: 0.9373 - val_accuracy: 0.8353
# Epoch 228/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0543 - accuracy: 0.9806 - val_loss: 0.9428 - val_accuracy: 0.8381
# Epoch 229/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0509 - accuracy: 0.9823 - val_loss: 0.9358 - val_accuracy: 0.8386
# Epoch 230/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0505 - accuracy: 0.9826 - val_loss: 0.9405 - val_accuracy: 0.8384
# Epoch 231/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0515 - accuracy: 0.9817 - val_loss: 0.9336 - val_accuracy: 0.8399
# Epoch 232/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0512 - accuracy: 0.9818 - val_loss: 0.9405 - val_accuracy: 0.8374
# Epoch 233/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0493 - accuracy: 0.9828 - val_loss: 0.9500 - val_accuracy: 0.8392
# Epoch 234/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0497 - accuracy: 0.9832 - val_loss: 0.9421 - val_accuracy: 0.8392
# Epoch 235/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0500 - accuracy: 0.9819 - val_loss: 0.9428 - val_accuracy: 0.8390
# Epoch 236/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0492 - accuracy: 0.9826 - val_loss: 0.9453 - val_accuracy: 0.8413
# Epoch 237/3000
# 235/235 [==============================] - 4s 13ms/step - loss: 0.0500 - accuracy: 0.9824 - val_loss: 0.9478 - val_accuracy: 0.8372
# Epoch 238/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0519 - accuracy: 0.9822 - val_loss: 0.9413 - val_accuracy: 0.8401
# Epoch 239/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0502 - accuracy: 0.9826 - val_loss: 0.9460 - val_accuracy: 0.8405
# Epoch 240/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0483 - accuracy: 0.9830 - val_loss: 0.9472 - val_accuracy: 0.8384
# Epoch 241/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0501 - accuracy: 0.9826 - val_loss: 0.9532 - val_accuracy: 0.8391
# Epoch 242/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0496 - accuracy: 0.9827 - val_loss: 0.9540 - val_accuracy: 0.8417
# Epoch 243/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0478 - accuracy: 0.9832 - val_loss: 0.9364 - val_accuracy: 0.8404
# Epoch 244/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0489 - accuracy: 0.9829 - val_loss: 0.9429 - val_accuracy: 0.8413
# Epoch 245/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0490 - accuracy: 0.9830 - val_loss: 0.9466 - val_accuracy: 0.8377
# Epoch 246/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0478 - accuracy: 0.9833 - val_loss: 0.9558 - val_accuracy: 0.8384
# Epoch 247/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0492 - accuracy: 0.9828 - val_loss: 0.9505 - val_accuracy: 0.8410
# Epoch 248/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0506 - accuracy: 0.9825 - val_loss: 0.9573 - val_accuracy: 0.8385
# Epoch 249/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0487 - accuracy: 0.9827 - val_loss: 0.9519 - val_accuracy: 0.8399
# Epoch 250/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0470 - accuracy: 0.9835 - val_loss: 0.9553 - val_accuracy: 0.8401
# Epoch 251/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0472 - accuracy: 0.9836 - val_loss: 0.9649 - val_accuracy: 0.8400
# Epoch 252/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0483 - accuracy: 0.9829 - val_loss: 0.9581 - val_accuracy: 0.8383
# Epoch 253/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 0.9549 - val_accuracy: 0.8367
# Epoch 254/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0496 - accuracy: 0.9823 - val_loss: 0.9575 - val_accuracy: 0.8385
# Epoch 255/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0449 - accuracy: 0.9838 - val_loss: 0.9613 - val_accuracy: 0.8407
# Epoch 256/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0498 - accuracy: 0.9829 - val_loss: 0.9673 - val_accuracy: 0.8368
# Epoch 257/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0486 - accuracy: 0.9829 - val_loss: 0.9610 - val_accuracy: 0.8404
# Epoch 258/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0462 - accuracy: 0.9833 - val_loss: 0.9663 - val_accuracy: 0.8391
# Epoch 259/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 40ms/step - loss: 0.0474 - accuracy: 0.9838 - val_loss: 0.9689 - val_accuracy: 0.8376
# Epoch 260/3000
# 235/235 [==============================] - 4s 13ms/step - loss: 0.0437 - accuracy: 0.9850 - val_loss: 0.9702 - val_accuracy: 0.8392
# Epoch 261/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0457 - accuracy: 0.9839 - val_loss: 0.9720 - val_accuracy: 0.8403
# Epoch 262/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0452 - accuracy: 0.9837 - val_loss: 0.9642 - val_accuracy: 0.8384
# Epoch 263/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0431 - accuracy: 0.9845 - val_loss: 0.9780 - val_accuracy: 0.8383
# Epoch 264/3000
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0467 - accuracy: 0.9834 - val_loss: 0.9728 - val_accuracy: 0.8390
# Epoch 265/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0457 - accuracy: 0.9842 - val_loss: 0.9802 - val_accuracy: 0.8381
# Epoch 266/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0456 - accuracy: 0.9845 - val_loss: 0.9794 - val_accuracy: 0.8353
# Epoch 267/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0459 - accuracy: 0.9843 - val_loss: 0.9734 - val_accuracy: 0.8391
# Epoch 268/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0471 - accuracy: 0.9833 - val_loss: 0.9637 - val_accuracy: 0.8365
# Epoch 269/3000
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0471 - accuracy: 0.9837 - val_loss: 0.9751 - val_accuracy: 0.8377
# Epoch 270/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0408 - accuracy: 0.9851 - val_loss: 0.9799 - val_accuracy: 0.8385
# Epoch 271/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0432 - accuracy: 0.9848 - val_loss: 0.9810 - val_accuracy: 0.8368
# Epoch 272/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0447 - accuracy: 0.9847 - val_loss: 0.9855 - val_accuracy: 0.8388
# Epoch 273/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0425 - accuracy: 0.9849 - val_loss: 0.9957 - val_accuracy: 0.8398
# Epoch 274/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0453 - accuracy: 0.9837 - val_loss: 0.9818 - val_accuracy: 0.8390
# Epoch 275/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0426 - accuracy: 0.9850 - val_loss: 0.9834 - val_accuracy: 0.8377
# Epoch 276/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0428 - accuracy: 0.9848 - val_loss: 0.9826 - val_accuracy: 0.8389
# Epoch 277/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0451 - accuracy: 0.9841 - val_loss: 0.9912 - val_accuracy: 0.8372
# Epoch 278/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0447 - accuracy: 0.9840 - val_loss: 0.9878 - val_accuracy: 0.8365
# Epoch 279/3000
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0416 - accuracy: 0.9860 - val_loss: 0.9922 - val_accuracy: 0.8377
# Epoch 280/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0440 - accuracy: 0.9843 - val_loss: 0.9916 - val_accuracy: 0.8361
# Epoch 281/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.9948 - val_accuracy: 0.8390
# Epoch 282/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0435 - accuracy: 0.9849 - val_loss: 0.9982 - val_accuracy: 0.8390
# Epoch 283/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0445 - accuracy: 0.9847 - val_loss: 0.9943 - val_accuracy: 0.8377
# Epoch 284/3000
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 1ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 0s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 188/188 [==============================] - 1s 2ms/step
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0433 - accuracy: 0.9847 - val_loss: 0.9967 - val_accuracy: 0.8378
# Epoch 285/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0431 - accuracy: 0.9847 - val_loss: 0.9895 - val_accuracy: 0.8398
# Epoch 286/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0441 - accuracy: 0.9845 - val_loss: 0.9931 - val_accuracy: 0.8367
# Epoch 287/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0400 - accuracy: 0.9863 - val_loss: 1.0014 - val_accuracy: 0.8389
# Epoch 288/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0434 - accuracy: 0.9849 - val_loss: 1.0055 - val_accuracy: 0.8369
# Epoch 289/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 1.0093 - val_accuracy: 0.8376
# Epoch 290/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0451 - accuracy: 0.9842 - val_loss: 1.0015 - val_accuracy: 0.8373
# Epoch 291/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0415 - accuracy: 0.9853 - val_loss: 1.0006 - val_accuracy: 0.8401
# Epoch 292/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0431 - accuracy: 0.9852 - val_loss: 0.9933 - val_accuracy: 0.8409
# Epoch 293/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0450 - accuracy: 0.9840 - val_loss: 0.9994 - val_accuracy: 0.8399
# Epoch 294/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0417 - accuracy: 0.9854 - val_loss: 0.9948 - val_accuracy: 0.8404
# Epoch 295/3000
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0427 - accuracy: 0.9850 - val_loss: 0.9888 - val_accuracy: 0.8369
# Epoch 296/3000
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0436 - accuracy: 0.9846 - val_loss: 0.9894 - val_accuracy: 0.8429
# Epoch 297/3000
#  85/235 [=========>....................] - ETA: 1s - loss: 0.0405 - accuracy: 0.9857

# %%
with open(f'./Output/Spin/M{CFG.M}/model001_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','rb') as f:
    spin_A=pickle.loads(f.read())

with open(f'./Output/Spin/M{CFG.M}/model002_type{CFG.ini_type}_L{CFG.L}_C{CFG.C}_{CFG.train}.txt','rb') as f:
    spin_B=pickle.loads(f.read())

# %%
fig, ax = plt.subplots(figsize=(10,5))
for i, l in enumerate(CFG.layer_name_list):
    ax.plot(q2['time'],q2[l],label=f'layer{i}')
ax.set_xlabel('Epoch',fontsize=16)
ax.set_ylabel('q2', fontsize=16)
#ax.set_xscale('log')
ax.set_title(f'Train Data (M:{CFG.M} L:{CFG.L})',fontsize=16)
#ax.set_ylim(0,1)
ax.grid(axis='y')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
